# %%
# Basic libraries
import numpy as np
import pandas as pd

# Testing dataset Elbow zone
df = pd.read_csv("ClimateDataElbowzone.csv")

df
# Out:
#        DateTime  Modeled Historical  Historical Range (low)  \
# 0    1950-01-01              531.50                  418.05
# 1    1951-01-01              566.99                  458.57
# 2    1952-01-01              588.31                  474.92
# 3    1953-01-01              573.97                  464.87
# 4    1954-01-01              602.96                  484.05
# ..          ...                 ...                     ...
# 146  2096-01-01                 NaN                     NaN
# 147  2097-01-01                 NaN                     NaN
# 148  2098-01-01                 NaN                     NaN
# 149  2099-01-01                 NaN                     NaN
# 150  2100-01-01                 NaN                     NaN
#
#      Historical Range (high)  RCP 2.6 Median  RCP 2.6 Range (low)  \
# 0                     700.70             NaN                  NaN
# 1                     738.27             NaN                  NaN
# ...
