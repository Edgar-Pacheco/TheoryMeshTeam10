# %%
# Basic libraries
import numpy as np
import pandas as pd

df = pd.read_csv("estimateddata20y.csv", index_col = "REF_DATE")

df
# Out:
#              GEO           DGUID  Harvest disposition  \
# REF_DATE
# 2000      Canada  2016A000011124  Seeded area (acres)
# 2001      Canada  2016A000011124  Seeded area (acres)
# 2002      Canada  2016A000011124  Seeded area (acres)
# 2003      Canada  2016A000011124  Seeded area (acres)
# 2004      Canada  2016A000011124  Seeded area (acres)
# ...          ...             ...                  ...
# 2017      Canada  2016A000011124  Seeded area (acres)
# 2018      Canada  2016A000011124  Seeded area (acres)
# 2019      Canada  2016A000011124  Seeded area (acres)
# 2020      Canada  2016A000011124  Seeded area (acres)
# 2021      Canada  2016A000011124  Seeded area (acres)
#
#                           Type of crop    UOM  UOM_ID SCALAR_FACTOR  \
# REF_DATE
# 2000                            Barley  Acres      28         units
# 2001                            Barley  Acres      28         units
# 2002                            Barley  Acres      28         units
# ...
