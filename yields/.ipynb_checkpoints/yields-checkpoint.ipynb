# %%
from funcs import * # user defined helper functions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### ---Get Specific Climate Data---
# #### get_clim_data(file,kind='p50',temporal=True,ro=False)
# kind referes to the subtype in the larger model. p50 is assumped.</br>
# Use temporal=False only the case of monthly data, i.e. those files with 'month' in their title.</br>
# Use ro=True to round to nearest integer values.

# %%
get_clim_data('leth-tmax.csv').head(10)
# Out:
#       rcp26  rcp45  rcp85
# time
# 1950    5.8    5.8    5.8
# 1951    3.4    3.4    3.4
# 1952    3.7    3.7    3.7
# 1953    3.4    3.4    3.4
# 1954    4.9    4.9    4.9
# 1955    4.5    4.5    4.5
# 1956    5.8    5.8    5.8
# 1957    4.1    4.1    4.1
# 1958    3.1    3.1    3.1
# 1959    2.4    2.4    2.4

# %%
get_clim_data('leth-month-total-precip.csv',temporal=False).head(10)
# Out:
#           rcp26   rcp45   rcp85
# time
# 1950-01  23.312  23.372  23.226
# 1950-02  24.014  23.090  23.258
# 1950-03  18.458  18.404  18.360
# 1950-04  37.332  37.622  37.590
# 1950-05  43.494  43.936  43.934
# 1950-06  72.342  71.154  71.946
# 1950-07  23.690  23.730  23.878
# 1950-08  35.390  33.434  33.434
# 1950-09  34.764  34.842  34.878
# 1950-10  24.658  24.658  24.658

# %% [markdown]
# ### ---Choose province and crop type ---
# #### crop_dict(crop_type, province)
# Available provinces: Alberta, Saskatchewan, and British Columbia </br>
# Available crops: Barley, Canola, Mustard seed, and Wheat, all </br></br>
# Use spelling precisely as given above. </br></br>
# Returns a dictionary whose keys are the climate models rcp26, rcp45, and rcp85. </br>

# %%
crop = crop_dict('Barley','Alberta')
crop['rcp26']
# Out:
#       kg/hec  days > 32  frost free days  precipitation  mean temperature
# time
# 1976  2400.0   1.266667       117.966667     240.835333         64.772667
# 1977  2500.0   1.700000       122.933333     242.770667         63.342000
# 1978  2400.0   2.233333       121.166667     241.368667         64.820667
# 1979  2500.0   1.066667       122.333333     252.956000         64.345333
# 1980  2700.0   1.666667       120.233333     267.720667         63.804667
# 1981  2700.0   2.466667       120.600000     238.856000         64.137333
# 1982  2700.0   1.600000       123.966667     275.833333         63.194000
# 1983  2500.0   0.666667       121.966667     278.699333         63.237333
# 1984  2200.0   1.800000       123.366667     255.732667         65.346000
# 1985  2200.0   2.466667       120.433333     232.702667         64.346000
# 1986  3200.0   1.366667       121.900000     232.591333         64.088000
# 1987  2900.0   1.733333       118.100000     255.042000         63.642000
# 1988  3100.0   2.233333       125.833333     239.207333         65.449333
# 1989  2700.0   2.833333       125.566667     251.468000         65.478667
# 1990  3000.0   1.100000       122.666667     276.595333         64.656667
# 1991  2900.0   1.333333       121.500000     274.332667         64.048000
# 1992  2800.0   0.733333       124.800000     266.636667         62.582667
# 1993  3500.0   0.733333       120.966667     271.048000         63.916000
# 1994  3000.0   1.700000       117.800000     247.183333         63.636000
# 1995  3300.0   2.166667       122.833333     245.851333         63.546667
# 1996  3300.0   2.066667       124.400000     254.286667         65.720000
# 1997  3100.0   1.900000       126.266667     252.394000         66.291333
# 1998  3000.0   2.133333       126.200000     228.936000         66.256000
# 1999  3500.0   1.500000       128.033333     258.914000         65.979333
# 2000  3000.0   2.066667       127.600000     264.657333         67.779333
# 2001  2900.0   3.166667       125.800000     262.564000         66.970000
# 2002  2300.0   3.300000       127.833333     279.406000         67.742000
# 2003  3000.0   2.233333       128.400000     268.881333         67.614000
# 2004  3500.0   2.500000       127.733333     272.949333         67.482667
# 2005  3600.0   3.133333       128.400000     280.698667         66.790667
# 2006  3200.0   2.600000       127.700000     288.464000         67.363333
# 2007  3000.0   2.233333       132.800000     261.405333         68.702000
# 2008  3600.0   2.200000       125.633333     290.322667         65.283333
# 2009  3100.0   3.533333       126.066667     271.013333         66.622667
# 2010  3600.0   2.733333       132.300000     289.027333         67.515333
# 2011  3600.0   3.100000       130.633333     262.498000         69.198667
# 2012  3200.0   3.500000       130.500000     254.374000         69.584000
# 2013  4100.0   2.633333       130.200000     264.955333         68.152667
# 2014  3600.0   3.733333       131.733333     283.914000         68.392667
# 2015  3700.0   3.900000       130.466667     258.247333         69.818000
# 2016  4100.0   3.500000       127.900000     262.219333         70.644000
# 2017  3900.0   3.566667       135.700000     267.230667         70.267333
# 2018  3595.0   2.566667       133.700000     276.422667         69.112667
# 2019  3890.0   3.500000       134.500000     259.722667         69.814000
# 2020  3980.0   3.300000       130.933333     260.228667         69.043333

# %% [markdown]
# ### ---Plotting Data---
# #### crop_plot(data_frame,all=False)
# We can check the relationships that exist between the yield and the remain variables.

# %%
crop_plot(crop['rcp26'],all=True)

# %%
crop_plot(crop['rcp45'])

# %%
crop_plot(crop['rcp85'])

# %% [markdown]
# ### ---Regression---
# Many of the new ideas out there are that some bounded evolutionary data move sigmoidally with time. However, the carrying capacity is not assumed to be constant anymore. </br></br>
# Here, we can assume something like the carrying capacity is a function of the remaining variables, like cummulative precipitation, etc.

# %% [markdown]
# ### ---Testing---
# The yield data is given only until 2020. The climate models, however, include predictions until 2100. We can, therefore, use the years 2021-2020 as the test of the model.
